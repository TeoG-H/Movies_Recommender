# %% [markdown]
# # Movies Dataset - Data analysis

# %% [markdown]
# # 1. Load Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import ast

df=pd.read_csv("../date/letterboxd_top_movies.csv")
df.head()
print(f"Dataset loaded successfully! Shape: {df.shape}")
# Out:
# Dataset loaded successfully! Shape: (72, 9)

# %% [markdown]
# # 2. Data Overview

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72 entries, 0 to 71
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Title        72 non-null     object
#  1   Rating       72 non-null     float64
#  2   Link         72 non-null     object
#  3   Description  72 non-null     object
#  4   Cast         72 non-null     object
#  5   Directors    72 non-null     object
#  6   Producers    72 non-null     object
#  7   Genres       72 non-null     object
#  8   Themes       72 non-null     object
# dtypes: float64(1), object(8)
# memory usage: 5.2+ KB
# None

# %%
print(df.head())
# Out:
#                                                Title  Rating  \
# 0         Radiohead: In Rainbows - From the Basement    4.73
# 1                                   Band of Brothers    4.72
# 2                                           Harakiri    4.69
# 3                                  Stop Making Sense    4.68
# 4  No Half Measures: Creating the Final Season of...    4.68
#
#                                                 Link  \
# 0  https://letterboxd.com/film/radiohead-in-rainb...
# 1      https://letterboxd.com/film/band-of-brothers/
# 2              https://letterboxd.com/film/harakiri/
# 3     https://letterboxd.com/film/stop-making-sense/
# 4  https://letterboxd.com/film/no-half-measures-c...
#
#                                          Description  \
# 0  A live performance by Radiohead of their 2007 ...
# 1  Drawn from interviews with survivors of Easy C...
# 2  Down-on-his-luck veteran Tsugumo Hanshirō ente...
# 3  A concert film documenting Talking Heads at th...
# 4  A documentary about the making of season five ...
#
#                                                 Cast  \
# 0  ['Thom Yorke', 'Jonny Greenwood', 'Colin Green...
# 1  ['Michael Cudlitz', 'Rick Gomez', 'Scott Grime...
# 2  ['Tatsuya Nakadai', 'Akira Ishihama', 'Shima I...
# 3  ['David Byrne', 'Chris Frantz', 'Jerry Harriso...
# 4  ['Bryan Cranston', 'Aaron Paul', 'Anna Gunn', ...
#
#                                            Directors  \
# 0                                  ['David Barnard']
# 1  ['Phil Alden Robinson', 'Richard Loncraine', '...
# 2                               ['Masaki Kobayashi']
# 3                                 ['Jonathan Demme']
# 4                              ['Stuart Richardson']
#
#                                            Producers  \
# 0  ['Dilly Gent', 'Nigel Godrich', 'James Chads',...
# 1  ['Terri Depaolo', 'Bruce Everett', 'Ivan Schwa...
# 2            ["Gin'ichi Kishimoto", 'Tatsuo Hosoya']
# 3                                  ['Gary Goetzman']
# 4                              ['Stuart Richardson']
#
#                            Genres  \
# 0                       ['Music']
# 1                ['Drama', 'War']
# 2  ['History', 'Drama', 'Action']
# 3        ['Music', 'Documentary']
# 4                 ['Documentary']
#
#                                               Themes
# 0                                                 []
# 1  ['War and historical adventure', 'Epic history...
# 2  ['Epic heroes', 'Powerful poetic and passionat...
# 3  ['Song and dance', 'Legendary musicians and st...
# 4                                                 []

# %%
df.describe()
# Out:
#             Rating
# count  2160.000000
# mean      4.208713
# std       0.126827
# min       4.060000
# 25%       4.110000
# 50%       4.180000
# 75%       4.280000
# max       4.730000

# %% [markdown]
# # 3. Data Visualization

# %%
plt.figure(figsize=(10, 6))
plt.hist(df['Rating'], bins=30, edgecolor='black', color='skyblue', alpha=0.7)
mean_rating = df['Rating'].mean()
plt.axvline(mean_rating, color='red', linestyle='--', linewidth=2, 
            label=f'Mean: {mean_rating:.2f}')


plt.title('Distribution of movies ratings', fontsize=16, fontweight='bold')
plt.xlabel('Rating', fontsize=12)
plt.ylabel('Number of movies', fontsize=12)
plt.legend()
plt.grid(alpha=0.3)

plt.tight_layout()
plt.savefig('../date/Screenshots/rating_distribution.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
    
df['Genres'] = df['Genres'].apply(ast.literal_eval)  # le trnasforma din stringuri in obiecte cu care pot lucra

all_genres = []
for genres_list in df['Genres']:
    all_genres.extend(genres_list)

genre_counts = pd.Series(all_genres).value_counts().head(10)

plt.figure(figsize=(10,6))
genre_counts.plot(kind='barh', color='coral', edgecolor='black')
plt.title('Top 10 Most Common Genres', fontsize=16, fontweight='bold')
plt.xlabel('Number of movies', fontsize=12)
plt.ylabel('Genre', fontsize=12)
plt.gca().invert_yaxis()
plt.grid(alpha=0.3, axis='x')
plt.tight_layout()
plt.savefig('../date/Screenshots/top_genres.png', dpi=300, bbox_inches='tight')
plt.show()

print(f"Found {len(set(all_genres))} unique genres")
# Out:
# Found 16 unique genres
